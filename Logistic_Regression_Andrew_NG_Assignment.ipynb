# %% [markdown]
# <a href="https://colab.research.google.com/github/ashu433/Machine-Learning-Codes-and-Assignment/blob/main/Logistic_Regression_Andrew_NG_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import copy, math

# %% [markdown]
# # **Using Linear Regression**

# %%
x_train = np.array([0., 1, 2, 3, 4, 5])
y_train = np.array([0,  0, 0, 1, 1, 1])
X_train2 = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_train2 = np.array([0, 0, 0, 1, 1, 1])

# %%
# Plot data points where y_train == 0
plt.scatter(x_train[y_train == 0], y_train[y_train == 0], color='blue', marker='o', label='y_train=0')

# Plot data points where y_train == 1
plt.scatter(x_train[y_train == 1], y_train[y_train == 1], color='red', marker='x', label='y_train=1')

# Add labels and legend
plt.xlabel('x_train')
plt.ylabel('y_train')
plt.legend()

# Show the plot
plt.show()

# %%
plt.scatter(X_train2[y_train2 == 0][:, 0], X_train2[y_train2 == 0][:, 1], color='blue', marker='o', label='y_train=0')

# Plot data points where y_train2 == 1
plt.scatter(X_train2[y_train2 == 1][:, 0], X_train2[y_train2 == 1][:, 1], color='red', marker='x', label='y_train=1')

# Add labels and legend
plt.xlabel('X dimension 1')
plt.ylabel('X dimension 2')
plt.legend()

# Show the plot
plt.show()

# %%
x_train = np.array([0., 1, 2, 3, 4, 5])
y_train = np.array([0,  0, 0, 1, 1, 1])

# %%
x_train=x_train.reshape(-1, 1)

# %%
linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = linear_model.predict(x_train)

# %%
y_classified = (y_pred >= 0.5).astype(int)
y_classified
# Out:
# array([0, 0, 0, 1, 1, 1])

# %%
plt.scatter(x_train[y_train == 0], y_train[y_train == 0], color='blue', marker='o', label='Actual y_train=0')
plt.scatter(x_train[y_train == 1], y_train[y_train == 1], color='red', marker='x', label='Actual y_train=1')

# Plot the regression line
plt.plot(x_train, y_pred, color='green', label='Regression Line')

# Plot the classified points after applying the threshold
plt.scatter(x_train[y_classified == 0], y_classified[y_classified == 0], color='cyan', marker='o', label='Predicted y=0', facecolors='none')
plt.scatter(x_train[y_classified == 1], y_classified[y_classified == 1], color='magenta', marker='o', label='Predicted y=1', facecolors='none')

# Add labels and legend
plt.xlabel('x_train')
plt.ylabel('y_train / predicted y')
plt.legend()

# Show the plot
plt.show()

# %%
print(f"The slope of the linear regression model is {linear_model.coef_} and the intercept is {linear_model.intercept_}")
# Out:
# The slope of the linear regression model is [0.25714286] and the intercept is -0.1428571428571428

# %% [markdown]
# # **Using Sigmiod Function**

# %%
input_array = np.array([1,2,3])
exp_array = np.exp(-input_array)

print("Input to exp:", input_array)
print("Output of exp:", exp_array)
# Out:
# Input to exp: [1 2 3]
# Output of exp: [0.36787944 0.13533528 0.04978707]

# %%
# Input is a single number
input_val = 1
exp_val = np.exp(input_val)

print("Input to exp:", input_val)
print("Output of exp:", exp_val)
# Out:
# Input to exp: 1
# Output of exp: 2.718281828459045

# %%
def sigmiod(z):
  return (1/(1+np.exp(-z)))

# %%
z_tmp = np.arange(-10,11)
y = sigmiod(z_tmp)
np.set_printoptions(precision=3)
print("Input (z), Output (sigmoid(z))")
print(np.c_[z_tmp, y])
# Out:
# Input (z), Output (sigmoid(z))
# [[-1.000e+01  4.540e-05]
#  [-9.000e+00  1.234e-04]
#  [-8.000e+00  3.354e-04]
#  [-7.000e+00  9.111e-04]
#  [-6.000e+00  2.473e-03]
#  [-5.000e+00  6.693e-03]
#  [-4.000e+00  1.799e-02]
#  [-3.000e+00  4.743e-02]
#  [-2.000e+00  1.192e-01]
#  [-1.000e+00  2.689e-01]
#  [ 0.000e+00  5.000e-01]
#  [ 1.000e+00  7.311e-01]
#  [ 2.000e+00  8.808e-01]
#  [ 3.000e+00  9.526e-01]
#  [ 4.000e+00  9.820e-01]
#  [ 5.000e+00  9.933e-01]
#  [ 6.000e+00  9.975e-01]
#  [ 7.000e+00  9.991e-01]
#  [ 8.000e+00  9.997e-01]
#  [ 9.000e+00  9.999e-01]
#  [ 1.000e+01  1.000e+00]]

# %%
fig,ax = plt.subplots(1,1,figsize=(5,3))
ax.plot(z_tmp, y, c="b")

ax.set_title("Sigmoid function")
ax.set_ylabel('sigmoid(z)')
ax.set_xlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
x_train = np.array([0., 1, 2, 3, 4, 5])
y_train = np.array([0,  0, 0, 1, 1, 1])

w_in = np.zeros((1))
b_in = 0

# %%
plt.scatter(x_train[y_train == 0], y_train[y_train == 0], color='blue', marker='o', label='y_train=0')
plt.scatter(x_train[y_train == 1], y_train[y_train == 1], color='red', marker='x', label='y_train=1')

# Add labels and legend
plt.xlabel('x_train')
plt.ylabel('y_train')
plt.legend()

# Show the plot
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
x_train = np.array([0., 1, 2, 3, 4, 5]).reshape(-1, 1)  # Reshaping for sklearn which expects a 2D array for X
y_train = np.array([0,  0, 0, 1, 1, 1])

# %%
log_reg = LogisticRegression()
log_reg.fit(x_train, y_train)
y_pred = log_reg.predict(x_train)
print("Predicted values:", y_pred)
# Out:
# Predicted values: [0 0 0 1 1 1]

# %%
# x_range = np.linspace(0, 5, 100).reshape(-1, 1)
# y_prob = log_reg.predict_proba(x_range)[:, 1]

# %%
plt.scatter(x_train, y_train, color='blue', label='Actual data')
plt.plot(x_train, y_pred, color='red', label='Logistic Regression Curve')
plt.xlabel('x_train')
plt.ylabel('Probability of y_train=1')
plt.legend()
plt.show()

# %% [markdown]
# # **Decision Boundary**

# %%
X = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y = np.array([0, 0, 0, 1, 1, 1]).reshape(-1,1)

# %%
# Plotting for y = 0
plt.scatter(X[y.ravel() == 0, 0], X[y.ravel() == 0, 1], color='blue', marker='o', label='y=0')

# Plotting for y = 1
plt.scatter(X[y.ravel() == 1, 0], X[y.ravel() == 1, 1], color='red', marker='x', label='y=1')

# Labels and legend
plt.xlabel('X1')
plt.ylabel('X2')
plt.legend()
plt.title('Scatter plot of X based on y values')

# Show plot
plt.show()

# %%
plt.scatter(X[y.ravel() == 0, 0], X[y.ravel() == 0, 1], color='blue', marker='o', label='y=0')
plt.scatter(X[y.ravel() == 1, 0], X[y.ravel() == 1, 1], color='red', marker='x', label='y=1')

# Create a grid of points
x0_vals = np.linspace(0, 4, 100)  # Values for X0
x1_vals = np.linspace(0, 4, 100)  # Values for X1
X0, X1 = np.meshgrid(x0_vals, x1_vals)

# Calculate the equation values for each point on the grid
Z = -3 + X0 + X1  # This is the equation -3 + X0 + X1

# Plot the decision boundary (where -3 + X0 + X1 = 0)
plt.contour(X0, X1, Z, levels=[0], colors='k', linestyles='--')

# Fill the areas based on the sign of -3 + X0 + X1
plt.contourf(X0, X1, Z, levels=[-np.inf, 0, np.inf], colors=['blue', 'red'], alpha=0.2)

# Labels and legend
plt.xlabel('X0')
plt.ylabel('X1')
plt.legend()
plt.title('Decision boundary and shaded areas')

# Show the plot
plt.show()

# %% [markdown]
# # **Logistic Loss**

# %%
x_train = np.array([0., 1, 2, 3, 4, 5],dtype=np.longdouble)
y_train = np.array([0,  0, 0, 1, 1, 1],dtype=np.longdouble)

# %%
# Plot data points where y_train == 0
plt.scatter(x_train[y_train == 0], y_train[y_train == 0], color='blue', marker='o', label='y=0')

# Plot data points where y_train == 1
plt.scatter(x_train[y_train == 1], y_train[y_train == 1], color='red', marker='x', label='y=1')

# Add labels and legend
plt.xlabel('x_train')
plt.ylabel('y_train')
plt.legend()

# Show the plot
plt.show()

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def cost_function(w, b):
    z = w * x_train + b
    predictions=sigmoid(z)
    cost = np.mean((predictions - y_train) ** 2)  # Mean Squared Error
    return cost

# %%
w_range = np.linspace(-10, 10, 100)
b_range = np.linspace(-10, 10, 100)
W, B = np.meshgrid(w_range, b_range)
cost_values = np.zeros(W.shape)

# %%
for i in range(W.shape[0]):
    for j in range(W.shape[1]):
        cost_values[i, j] = cost_function(W[i, j], B[i, j])

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(W, B, cost_values, cmap='viridis')

ax.set_xlabel('Weight (w)')
ax.set_ylabel('Bias (b)')
ax.set_zlabel('Cost')
ax.set_title('3D Surface Plot of Cost Function')

plt.show()

# %%
def cost_function_modified_logistic_loss(w, b):
    z = w * x_train + b
    predictions=sigmoid(z)
    cost = -np.mean(y_train * np.log(predictions) + (1 - y_train) * np.log(1 - predictions))
    return cost

# %%
w_range = np.linspace(-10, 10, 100)
b_range = np.linspace(-10, 10, 100)
W, B = np.meshgrid(w_range, b_range)
cost_values = np.zeros(W.shape)

# %%
for i in range(W.shape[0]):
    for j in range(W.shape[1]):
        cost_values[i, j] = cost_function_modified_logistic_loss(W[i, j], B[i, j])
# Out:
# <ipython-input-33-d3e1fc7d25b2>:4: RuntimeWarning: divide by zero encountered in log
#   cost = -np.mean(y_train * np.log(predictions) + (1 - y_train) * np.log(1 - predictions))
# <ipython-input-33-d3e1fc7d25b2>:4: RuntimeWarning: invalid value encountered in multiply
#   cost = -np.mean(y_train * np.log(predictions) + (1 - y_train) * np.log(1 - predictions))

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(W, B, cost_values, cmap='viridis')

ax.set_xlabel('Weight (w)')
ax.set_ylabel('Bias (b)')
ax.set_zlabel('Cost')
ax.set_title('3D Surface Plot of Cost Function')

plt.show()

# %%
X_input= np.linspace(0, 100, 1000)
Y=-np.log(X_input)

plt.plot(1-X_input,Y)
plt.xlim(0, 1)
# Out:
# <ipython-input-37-2ae84b41221f>:2: RuntimeWarning: divide by zero encountered in log
#   Y=-np.log(X_input)
# (0.0, 1.0)

# %% [markdown]
# # Cost Function for Logistic Regression

# %%
X= np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])  #(m,n)
y = np.array([0, 0, 0, 1, 1, 1])

# %%
# Plotting for y = 0
plt.scatter(X[y.ravel() == 0, 0], X[y.ravel() == 0, 1], color='blue', marker='o', label='y=0')

# Plotting for y = 1
plt.scatter(X[y.ravel() == 1, 0], X[y.ravel() == 1, 1], color='red', marker='x', label='y=1')

# Labels and legend
plt.xlabel('X1')
plt.ylabel('X2')
plt.legend()
plt.title('Scatter plot of X based on y values')

# Show plot
plt.show()

# %%
X.shape
# Out:
# (6, 2)

# %%
def cost_function_logistic_function(X,y,w,b):
  m=X.shape[0]
  cost=0
  for i in range(m):
    z_compute=np.dot(X[i],w)+b
    f_wb=sigmoid(z_compute)
    cost=cost-y[i]*np.log(f_wb)-(1-y[i])*np.log(1-f_wb)

  cost=cost/m

  return cost

# %%
w_tmp = np.array([1,1])
b_tmp = -3
cost_function_logistic_function(X,y,w_tmp,b_tmp)
# Out:
# 0.36686678640551745

# %%
w_tmp = np.array([1,1])
b_tmp = -4
cost_function_logistic_function(X,y,w_tmp,b_tmp)
# Out:
# 0.5036808636748461

# %% [markdown]
# # **Gradient Descent for Logistic Regression**

# %%
X = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y = np.array([0, 0, 0, 1, 1, 1])

# %%
# Plotting for y = 0
plt.scatter(X[y.ravel() == 0, 0], X[y.ravel() == 0, 1], color='blue', marker='o', label='y=0')

# Plotting for y = 1
plt.scatter(X[y.ravel() == 1, 0], X[y.ravel() == 1, 1], color='red', marker='x', label='y=1')

# Labels and legend
plt.xlabel('X1')
plt.ylabel('X2')
plt.legend()
plt.title('Scatter plot of X based on y values')

# Show plot
plt.show()

# %%
def compute_gradient_logistic(X, y, w, b):
  m,n=X.shape
  dj_dw=np.zeros((n,))
  dj_db=0.

  for i in range(m):
    z_in=np.dot(X[i],w)+b
    f_wb=sigmoid(z_in)
    err=f_wb-y[i]
    for j in range(n):
      dj_dw[j]=dj_dw[j] + err * X[i,j]

    dj_db=dj_db+err

  dj_dw=dj_dw/m
  dj_db=dj_db/m

  return dj_dw, dj_db

# %%
X_tmp = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_tmp = np.array([0, 0, 0, 1, 1, 1])
w_tmp = np.array([2.,3.])
b_tmp = 1.
dj_db_tmp, dj_dw_tmp = compute_gradient_logistic(X_tmp, y_tmp, w_tmp, b_tmp)
print(f"dj_dw: {dj_db_tmp}" )
print(f"dj_db: {dj_dw_tmp.tolist()}" )
# Out:
# dj_dw: [0.498 0.499]
# dj_db: 0.49861806546328574

# %%
import math

# %%
def gradient_descent(X, y, w_in, b_in, alpha, num_iters):
  J_history = []
  w = copy.deepcopy(w_in)
  b = b_in

  for i in range(num_iters):
    dj_dw, dj_db = compute_gradient_logistic(X, y, w, b)

    w = w - alpha * dj_dw
    b = b - alpha * dj_db

    cost_out=cost_function_logistic_function(X,y,w,b)
    # print(f"Cost: {cost_out}")

    if i<100000:      # prevent resource exhaustion
        J_history.append( cost_function_logistic_function(X,y,w,b) )

    # Print cost every at intervals 10 times or as many iterations if < 10
    if i% math.ceil(num_iters / 10) == 0:
        print(f"Iteration {i:4d}: Cost {J_history[-1]}   ")

  return w, b, J_history

# %%
X_train = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_train = np.array([0, 0, 0, 1, 1, 1])

# %%
w_tmp  = np.zeros_like(X_train[0])
b_tmp  = 0.
alph = 0.1
iters = 10000

w_out, b_out, _ = gradient_descent(X_train, y_train,w_tmp, b_tmp, alph, iters)
print(f"\nupdated parameters: w:{w_out}, b:{b_out}")
# Out:
# Iteration    0: Cost 0.684610468560574
# Iteration 1000: Cost 0.1590977666870457
# Iteration 2000: Cost 0.08460064176930078
# Iteration 3000: Cost 0.05705327279402531
# Iteration 4000: Cost 0.04290759421682
# Iteration 5000: Cost 0.03433847729884557
# Iteration 6000: Cost 0.02860379802212006
# Iteration 7000: Cost 0.02450156960879306
# Iteration 8000: Cost 0.02142370332569295
# Iteration 9000: Cost 0.019030137124109114
#
# updated parameters: w:[5.281 5.078], b:-14.222409982019837

# %% [markdown]
# # **Using SK lear Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression

# %%
X_train = np.array([[0.5, 1.5], [1, 1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_train = np.array([0, 0, 0, 1, 1, 1])

# Create the logistic regression model and fit it to the data
model = LogisticRegression()
model.fit(X_train, y_train)

# Function to plot decision boundary
def plot_decision_boundary(model, X, y):
    # Create a mesh to plot in
    x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
    y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01), np.arange(y_min, y_max, 0.01))

    # Predict the label for each point in the mesh
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # Plot the decision boundary
    plt.contourf(xx, yy, Z, alpha=0.8)
    plt.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', marker='o', s=100)
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.title('Decision Boundary for Logistic Regression')
    plt.show()

# Plot decision boundary
plot_decision_boundary(model, X_train, y_train)

# %% [markdown]
# # **Assignment Code**

# %%
import copy, math

# %%
def compute_gradient_logistic(X, y, w, b):
    """
    Computes the gradient for linear regression

    Args:
      X (ndarray (m,n): Data, m examples with n features
      y (ndarray (m,)): target values
      w (ndarray (n,)): model parameters
      b (scalar)      : model parameter
    Returns
      dj_dw (ndarray (n,)): The gradient of the cost w.r.t. the parameters w.
      dj_db (scalar)      : The gradient of the cost w.r.t. the parameter b.
    """
    m,n = X.shape
    dj_dw = np.zeros((n,))                           #(n,)
    dj_db = 0.

    for i in range(m):
        f_wb_i = sigmoid(np.dot(X[i],w) + b)          #(n,)(n,)=scalar
        err_i  = f_wb_i  - y[i]                       #scalar
        for j in range(n):
            dj_dw[j] = dj_dw[j] + err_i * X[i,j]      #scalar
        dj_db = dj_db + err_i
    dj_dw = dj_dw/m                                   #(n,)
    dj_db = dj_db/m                                   #scalar

    return dj_db, dj_dw

# %%
def gradient_descent(X, y, w_in, b_in, alpha, num_iters):
    """
    Performs batch gradient descent

    Args:
      X (ndarray (m,n)   : Data, m examples with n features
      y (ndarray (m,))   : target values
      w_in (ndarray (n,)): Initial values of model parameters
      b_in (scalar)      : Initial values of model parameter
      alpha (float)      : Learning rate
      num_iters (scalar) : number of iterations to run gradient descent

    Returns:
      w (ndarray (n,))   : Updated values of parameters
      b (scalar)         : Updated value of parameter
    """
    # An array to store cost J and w's at each iteration primarily for graphing later
    J_history = []
    w = copy.deepcopy(w_in)  #avoid modifying global w within function
    print(w)
    b = b_in

    for i in range(num_iters):
        # Calculate the gradient and update the parameters
        dj_db, dj_dw = compute_gradient_logistic(X, y, w, b)

        # Update Parameters using w, b, alpha and gradient
        w = w - alpha * dj_dw
        b = b - alpha * dj_db

        # Save cost J at each iteration
        if i<100000:      # prevent resource exhaustion
            J_history.append( cost_function_logistic_function(X,y,w,b) )

        # Print cost every at intervals 10 times or as many iterations if < 10
        if i% math.ceil(num_iters / 10) == 0:
            print(f"Iteration {i:4d}: Cost {J_history[-1]}   ")

    return w, b, J_history         #return final w,b and J history for graphing

# %%
w_tmp  = np.zeros_like(X_train[0])
b_tmp  = 0.
alph = 0.1
iters = 10000

w_out, b_out, _ = gradient_descent(X_train, y_train, w_tmp, b_tmp, alph, iters)
print(f"\nupdated parameters: w:{w_out}, b:{b_out}")
# Out:
# [0. 0.]
# Iteration    0: Cost 0.684610468560574
# Iteration 1000: Cost 0.1590977666870457
# Iteration 2000: Cost 0.08460064176930078
# Iteration 3000: Cost 0.05705327279402531
# Iteration 4000: Cost 0.04290759421682
# Iteration 5000: Cost 0.03433847729884557
# Iteration 6000: Cost 0.02860379802212006
# Iteration 7000: Cost 0.02450156960879306
# Iteration 8000: Cost 0.02142370332569295
# Iteration 9000: Cost 0.019030137124109114
#
# updated parameters: w:[5.281 5.078], b:-14.222409982019837

# %% [markdown]
# # **Regularized Cost and Gradient**

# %%
def compute_cost_linear_reg(X, y, w, b, lambda_ = 1):
  m=X.shape[0]
  n=len(w)
  cost=0
  regu=0

  for i in range(m):
    f_wb=np.dot(X[i],w)+b
    err=(f_wb-y[i])**2
    cost=cost+err

  cost=cost/(2*m)

  for j in range(n):
    regu=regu+(w[j]**2)

  regu=regu*(lambda_/(2*m))

  total_cost=cost+regu

  return total_cost

# %%
np.random.seed(1)
X_tmp = np.random.rand(5,6)
y_tmp = np.array([0,1,0,1,0])
w_tmp = np.random.rand(X_tmp.shape[1]).reshape(-1,)-0.5
b_tmp = 0.5
lambda_tmp = 0.7
cost_tmp = compute_cost_linear_reg(X_tmp, y_tmp, w_tmp, b_tmp, lambda_tmp)

print("Regularized cost:", cost_tmp)
# Out:
# Regularized cost: 0.07917239320214277

# %%
def compute_cost_logistic_reg(X, y, w, b, lambda_ = 1):
  m=X.shape[0]
  n=len(w)
  cost=0
  regu=0

  for i in range(m):
    f_wb=sigmoid(np.dot(X[i],w)+b)
    cost=cost+(-y[i]*np.log(f_wb)-(1-y[i])*np.log(1-f_wb))

  cost=cost/m

  for j in range(n):
    regu=regu+(w[j]**2)

  regu=regu*(lambda_/(2*m))

  total_cost=cost+regu

  return total_cost

# %%
np.random.seed(1)
X_tmp = np.random.rand(5,6)
y_tmp = np.array([0,1,0,1,0])
w_tmp = np.random.rand(X_tmp.shape[1]).reshape(-1,)-0.5
b_tmp = 0.5
lambda_tmp = 0.7
cost_tmp = compute_cost_logistic_reg(X_tmp, y_tmp, w_tmp, b_tmp, lambda_tmp)

print("Regularized cost:", cost_tmp)
# Out:
# Regularized cost: 0.6850849138741673

# %%
def compute_gradient_linear_reg(X, y, w, b, lambda_):
  m,n=X.shape
  dj_dw=np.zeros((n,))
  dj_db=0

  for i in range(m):
    err = (np.dot(X[i], w) + b) - y[i]
    for j in range(n):
      dj_dw[j] = dj_dw[j] + err * X[i, j]

    dj_db=dj_db + err

  dj_dw=dj_dw/m
  dj_db=dj_db/m

  for k in range(n):
    dj_dw[k]=dj_dw[k]+(lambda_/m) * w[k]

  return dj_db, dj_dw

# %%
np.random.seed(1)
X_tmp = np.random.rand(5,3)
y_tmp = np.array([0,1,0,1,0])
w_tmp = np.random.rand(X_tmp.shape[1])
b_tmp = 0.5
lambda_tmp = 0.7
dj_db_tmp, dj_dw_tmp =  compute_gradient_linear_reg(X_tmp, y_tmp, w_tmp, b_tmp, lambda_tmp)

print(f"dj_db: {dj_db_tmp}", )
print(f"Regularized dj_dw:\n {dj_dw_tmp.tolist()}", )
# Out:
# dj_db: 0.6648774569425726
# Regularized dj_dw:
#  [0.29653214748822276, 0.4911679625918033, 0.21645877535865857]

# %%
def compute_gradient_logistic_reg(X, y, w, b, lambda_):
  m,n=X.shape
  dj_dw=np.zeros((n,))
  dj_db=0

  for i in range(m):
    err = (sigmoid(np.dot(X[i], w) + b)) - y[i]
    for j in range(n):
      dj_dw[j] = dj_dw[j] + err * X[i, j]

    dj_db=dj_db + err

  dj_dw=dj_dw/m
  dj_db=dj_db/m

  for k in range(n):
    dj_dw[k]=dj_dw[k]+(lambda_/m) * w[k]

  return dj_db, dj_dw

# %%
np.random.seed(1)
X_tmp = np.random.rand(5,3)
y_tmp = np.array([0,1,0,1,0])
w_tmp = np.random.rand(X_tmp.shape[1])
b_tmp = 0.5
lambda_tmp = 0.7
dj_db_tmp, dj_dw_tmp =  compute_gradient_logistic_reg(X_tmp, y_tmp, w_tmp, b_tmp, lambda_tmp)

print(f"dj_db: {dj_db_tmp}", )
print(f"Regularized dj_dw:\n {dj_dw_tmp.tolist()}", )
# Out:
# dj_db: 0.341798994972791
# Regularized dj_dw:
#  [0.17380012933994293, 0.32007507881566943, 0.10776313396851499]
